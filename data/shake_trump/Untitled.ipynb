# %%
import pickle

# %%
vocab_file = "vocab.vocab"

# %%
with open(vocab_file, 'rb') as f:
    vocab_size, word2id, id2word = pickle.load(f)

# %%
print(vocab_size)
# Out:
# 11775

# %%
print(id2word)
# Out:
# ['<pad>', '<go>', '<eos>', '<unk>', 'fawn', 'nunnery', 'woods', 'spiders', 'hanging', 'woody', 'scold', 'benvolio', 'taj', 'bringing', '7pme', 'wooden', 'wednesday', 'sooth', 'mortgages', 'errors', 'crouch', 'china', 'kids', 'controversy', 'natures', 'golden', 'lengthen', 'garter', 'stern', 'dnc', 'music', 'therefore', 'yahoo', 'circumstances', 'morally', 'locked', 'unjust', 'reignier', 'want', "by'r", "by't", 'absolute', 'travel', 'wrong', 'gardon', '18th', 'welcomed', 'rewarded', 'welcomes', 'fit', 'fix', 'discourse', 'fig', 'fie', 'wales', 'effects', 'sixteen', "'od", 'arrow', 'burial', 'allay', 'oprah', 'mason', 'encourage', 'sheep', 'strato', 'clamorous', 'knight', 'windmills', 'renovated', 'service', 'needed', 'master', 'rewards', 'madison', 'positively', 'idly', 'idle', 'feeling', 'longs', 'pomp', 'dozen', 'affairs', 'wholesome', 'hymen', 'mouth', 'reverence', 'expound', 'nettle', 'purged', 'saying', 'serving-man', 'tempted', 'apace', 'kerns', 'rico', 'bliss', 'rick', 'rich', 
# ...

# %%
word2id['trump']
# Out:
# 11264
